# %%
import requests
import pandas as pd 
from bs4 import BeautifulSoup

# %%
import requests

headers = {
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
  'accept-encoding': 'gzip, deflate, br',
  'accept-language': 'en-US,en;q=0.9',
  'cache-control': 'max-age=0',
  'cookie': 'yourcookie',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 12239.92.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.136 Safari/537.36',
}

response = requests.get("https://quizlet.com/796287248/exercise-and-health-exam-4-flash-cards/", headers=headers)

soup = BeautifulSoup(response.text,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-us"><head><meta charset="utf-8"/><link href="/_next/static/media/q-twilight.e27821d9.png" rel="shortcut icon"/><link as="fetch" crossorigin="anonymous" href="/_next/static/media/icons.850659be.svg" rel="preload"/><script>(function() {
#     var ajax = new XMLHttpRequest();
#     ajax.open('GET', "/_next/static/media/icons.850659be.svg");
#     ajax.send();
#     ajax.onload = function () {
#       if (ajax.status === 404) {
#         return Rollbar.error('Error fetching SVG sprite sheet (not found)');
#       } else if (ajax.status !== 200) {
#         return Rollbar.warning('Error fetching SVG sprite sheet (bad response)', { code: ajax.status });
#       }
#       var div = document.createElement('div');
#       div.style.display = 'none';
#       div.innerHTML = ajax.responseText;
#       var waitForBody = setInterval(function() {
#         if (document.body) {
#           clearInterval(waitForBody);
# ...

# %%
soup.find_all("span")[9].text[-3:]
# Out:
# 'KEY'

# %%
f = [1,2,3]
k = [["one","two","three"],["four","five","six"],["seven","eight","nine"]]
dict(zip(f,k))
# Out:
# {1: ['one', 'two', 'three'],
#  2: ['four', 'five', 'six'],
#  3: ['seven', 'eight', 'nine']}

# %%
default = soup.find_all("span")[9:161]

# %%
flashcards = " ".join(x.text for x in default)

# %%
flashcards
# Out:
# "KEY Boyle's Law KEY if you decrease the volume of a container of gas and hold the temperature constant, the pressure from the gas will increase KEY Henry's Law KEY At a given temperature the solubility of a gas in a solution is directly proportional to the pressure of the gas KEY Dalton's Law KEY each gas contributes to total pressure in proportion to its relative abundance KEY Quiet breathing KEY no muscles are contracted, inhalation muscles (diaphragm and external intercostals) relax KEY Forced breathing KEY Active process; internal intercostals depress the ribs and abdominal muscles compress the abdomen KEY How does training affect lung volumes? KEY Decreases functional residual capacity and residual volume, increases vital capacity KEY Minute ventilation equation KEY VE = f  TV (breaths/min  tidal volume) KEY Restrictive diseases KEY pulmonary fibrosis, obesity, scoliosis, muscular dystrophy KEY Obstructive diseases KEY COPD, asthma, cystic fibrosis KEY How does FEV1 differ betw
# ...

# %%
flashcards.index(" B")
# Out:
# 3

# %%
key_list = [x.rstrip().lstrip() for x in flashcards.split("KEY") if flashcards.split("KEY").index(x)%2 != 0]

# %%
value_list = [x.rstrip().lstrip() for x in flashcards.split("KEY")[1:] if flashcards.split("KEY").index(x)%2 == 0]

# %%
key_list
# Out:
# ["Boyle's Law",
#  "Henry's Law",
#  "Dalton's Law",
#  'Quiet breathing',
#  'Forced breathing',
#  'How does training affect lung volumes?',
#  'Minute ventilation equation',
#  'Restrictive diseases',
#  'Obstructive diseases',
#  'How does FEV1 differ between restrictive and obstructive?',
#  'Ventilatory threshold and how it occurs',
#  'How does training affect ventilatory threshold?',
#  'What happens to respiration rate during hypo- and hypercapnia?',
#  'How do pH, temperature and BPG affect the Hb saturation curve?',
#  'How is CO2 transported?',
#  'How does the body compensate for metabolic acidosis?',
#  '3 things an exercise test should include for asthmatics',
#  'COPD exercise prescription considerations',
#  'Prolactin',
#  'GH',
#  'TSH',
#  'ACTH',
#  'FSH',
#  'LH',
#  'MSH',
#  'ADH',
#  'Oxytocin',
#  'Melatonin',
#  'ANP and BNP',
#  'Calcitriol',
#  'EPO',
#  'Renin',
#  'Response of catecholamines, insulin/glucagon, and thyroid hormones to training',
# ...

# %%
value_list
# Out:
# ['if you decrease the volume of a container of gas and hold the temperature constant, the pressure from the gas will increase',
#  'At a given temperature the solubility of a gas in a solution is directly proportional to the pressure of the gas',
#  'each gas contributes to total pressure in proportion to its relative abundance',
#  'no muscles are contracted, inhalation muscles (diaphragm and external intercostals) relax',
#  'Active process; internal intercostals depress the ribs and abdominal muscles compress the abdomen',
#  'Decreases functional residual capacity and residual volume, increases vital capacity',
#  'VE = f  TV (breaths/min  tidal volume)',
#  'pulmonary fibrosis, obesity, scoliosis, muscular dystrophy',
#  'COPD, asthma, cystic fibrosis',
#  'FEV1 is normal in restrictive and FVC is reduced. FEV1 is reduced compared to FVC in obstructive.',
# ...

# %%
key_list
# Out:
# ["Boyle's Law",
#  "Henry's Law",
#  "Dalton's Law",
#  'Quiet breathing',
#  'Forced breathing',
#  'How does training affect lung volumes?',
#  'Minute ventilation equation',
#  'Restrictive diseases',
#  'Obstructive diseases',
#  'How does FEV1 differ between restrictive and obstructive?',
#  'Ventilatory threshold and how it occurs',
#  'How does training affect ventilatory threshold?',
#  'What happens to respiration rate during hypo- and hypercapnia?',
#  'How do pH, temperature and BPG affect the Hb saturation curve?',
#  'How is CO2 transported?',
#  'How does the body compensate for metabolic acidosis?',
#  '3 things an exercise test should include for asthmatics',
#  'COPD exercise prescription considerations',
#  'Prolactin',
#  'GH',
#  'TSH',
#  'ACTH',
#  'FSH',
#  'LH',
#  'MSH',
#  'ADH',
#  'Oxytocin',
#  'Melatonin',
#  'ANP and BNP',
#  'Calcitriol',
#  'EPO',
#  'Renin',
#  'Response of catecholamines, insulin/glucagon, and thyroid hormones to training',
# ...

# %%
fcd = dict(zip(key_list,value_list))

# %%
pd.DataFrame(data={"Key":key_list,"Value":value_list})
# Out:
#                                           Key  \
# 0                                 Boyle's Law
# 1                                 Henry's Law
# 2                                Dalton's Law
# 3                             Quiet breathing
# 4                            Forced breathing
# ..                                        ...
# 71                                Aldosterone
# 72                                   Cortisol
# 73                          Adrenal androgens
# 74                             Catecholamines
# 75  Calcitriol increases the transcription of
#
#                                                 Value
# 0   if you decrease the volume of a container of g...
# 1   At a given temperature the solubility of a gas...
# 2   each gas contributes to total pressure in prop...
# 3   no muscles are contracted, inhalation muscles ...
# 4   Active process; internal intercostals depress ...
# ..                                                ...
# ...
